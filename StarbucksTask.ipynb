# %% [markdown]
# # Starbucks Dataset

# %% [markdown]
# ## Kütüphanelerin İmport Edilmesi

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Veri Setinin Okutulması

# %%
data = pd.read_csv("Starbucks satisfactory survey encode cleaned.csv")

# %% [markdown]
# ## Veri Setinin Analizi

# %%
data.head()
# Out:
#    Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0   1       1    1       0       0        3       0          1         0
# 1   2       1    1       0       0        3       2          0         1
# 2   3       0    1       2       0        2       0          1         2
# 3   4       1    1       0       0        3       2          0         2
# 4   5       0    1       0       0        2       2          1         1
#
#    membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 0               0  ...           3               1               1
# 1               0  ...           2               1               1
# 2               0  ...           3               1               1
# 3               1  ...           3               1               1
# 4               1  ...           3               1               1
#
#    promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
data.tail()
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
#      membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 108               0  ...           4               1               1
# 109               0  ...           5               1               1
# 110               1  ...           4               1               1
# 111               1  ...           4               1               1
# 112               1  ...           2               1               1
#
#      promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
data.shape
# Out:
# (113, 33)

# %%
data.isnull().sum()
# Out:
# Id                        0
# gender                    0
# age                       0
# status                    0
# income                    0
# visitNo                   0
# method                    0
# timeSpend                 0
# location                  0
# membershipCard            0
# itemPurchaseCoffee        0
# itempurchaseCold          0
# itemPurchasePastries      0
# itemPurchaseJuices        0
# itemPurchaseSandwiches    0
# itemPurchaseOthers        0
# spendPurchase             0
# productRate               0
# priceRate                 0
# promoRate                 0
# ambianceRate              0
# wifiRate                  0
# serviceRate               0
# chooseRate                0
# promoMethodApp            0
# promoMethodSoc            0
# promoMethodEmail          0
# promoMethodDeal           0
# promoMethodFriend         0
# promoMethodDisplay        0
# promoMethodBillboard      0
# promoMethodOthers         0
# loyal                     0
# ...

# %%
data.nunique()
# Out:
# Id                        113
# gender                      2
# age                         4
# status                      4
# income                      5
# visitNo                     4
# method                      4
# timeSpend                   5
# location                    3
# membershipCard              2
# itemPurchaseCoffee          1
# itempurchaseCold            1
# itemPurchasePastries        1
# itemPurchaseJuices          1
# itemPurchaseSandwiches      1
# itemPurchaseOthers          1
# spendPurchase               4
# productRate                 5
# priceRate                   5
# promoRate                   5
# ambianceRate                5
# wifiRate                    5
# serviceRate                 4
# chooseRate                  5
# promoMethodApp              1
# promoMethodSoc              1
# promoMethodEmail            1
# promoMethodDeal             1
# promoMethodFriend           1
# promoMethodDisplay          1
# promoMethodBillboard        1
# ...

# %%
df = data.copy()

# %%
df
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
# ...

# %%
df.shape
# Out:
# (113, 33)

# %%
df.head()
# Out:
#    Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0   1       1    1       0       0        3       0          1         0
# 1   2       1    1       0       0        3       2          0         1
# 2   3       0    1       2       0        2       0          1         2
# 3   4       1    1       0       0        3       2          0         2
# 4   5       0    1       0       0        2       2          1         1
#
#    membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 0               0  ...           3               1               1
# 1               0  ...           2               1               1
# 2               0  ...           3               1               1
# 3               1  ...           3               1               1
# 4               1  ...           3               1               1
#
#    promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
df.tail()
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
#      membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 108               0  ...           4               1               1
# 109               0  ...           5               1               1
# 110               1  ...           4               1               1
# 111               1  ...           4               1               1
# 112               1  ...           2               1               1
#
#      promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
df["gender"] #113 adet integer ifadeye sahibiz.
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 108    0
# 109    0
# 110    0
# 111    1
# 112    0
# Name: gender, Length: 113, dtype: int64

# %%
df[df["gender"] ==0] #Anketteki katılımcıların 54'ünün erkek olduğunu görüntülüyoruz
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 2      3       0    1       2       0        2       0          1         2
# 4      5       0    1       0       0        2       2          1         1
# 7      8       0    1       2       2        3       0          1         2
# 9     10       0    1       2       0        2       2          0         2
# 16    17       0    2       2       2        2       1          0         0
# 17    18       0    1       2       0        3       0          0         0
# 18    19       0    1       2       1        1       2          0         1
# 20    21       0    2       2       3        3       2          0         0
# 22    23       0    1       2       1        3       0          4         0
# 24    25       0    3       1       3        3       0          2         2
# 25    26       0    2       2       4        2       0          1         1
# ...

# %%
df[df["gender"] ==1] #Kalan 59 katılımcının ise Kadın müşterilerden oluştuğunu anlamış oluyoruz.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 3      4       1    1       0       0        3       2          0         2
# 5      6       1    1       0       0        3       0          1         2
# 6      7       1    1       0       0        3       0          0         0
# 8      9       1    1       0       0        3       1          0         2
# 10    11       1    1       0       0        3       0          0         2
# 11    12       1    1       0       0        3       0          1         2
# 12    13       1    1       0       0        1       2          0         1
# 13    14       1    1       0       0        3       2          0         1
# 14    15       1    1       0       0        3       2          0         0
# ...

# %% [markdown]
# ## Veri Setinin Görselleştirilmesi

# %%
sns.countplot(data=df, x='gender')
plt.title('Cinsiyet')
plt.xticks([0, 1], ['Erkek', 'Kadın'])
plt.xlabel('')
plt.show()
#Cinsiyet seçeneğinde 59 kadın ve 54 erkek bulunmaktadır.

# %%
df["age"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 108    3
# 109    1
# 110    1
# 111    1
# 112    1
# Name: age, Length: 113, dtype: int64

# %%
df[df["age"] ==0] #"0" 20 yaşın altındakileri ifade eder.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 37    38       0    0       0       0        3       0          2         2
# 46    50       0    0       0       0        3       1          0         0
# 48    52       1    0       0       0        3       0          0         2
# 50    54       1    0       0       0        3       1          0         2
# 54    58       0    0       0       0        2       0          1         2
# 55    59       0    0       0       0        2       0          0         1
# 75    80       1    0       0       0        3       2          0         2
# 98   105       0    0       0       0        3       1          1         2
# 104  114       1    0       0       0        3       2          0         2
# 106  116       0    0       0       0        0       2          0         2
#
#      membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# ...

# %%
df[df["age"] ==1] #"1" 20 - 29 yaş aralığını,
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 103  112       1    1       2       0        2       2          0         2
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
# ...

# %%
df[df["age"] ==2] #"2" 30 - 39 yaş aralığını ifade eder.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 16    17       0    2       2       2        2       1          0         0
# 20    21       0    2       2       3        3       2          0         0
# 25    26       0    2       2       4        2       0          1         1
# 26    27       0    2       2       4        3       1          0         1
# 32    33       1    2       2       1        3       2          0         2
# 39    40       0    2       2       2        3       2          0         0
# 43    46       1    2       0       2        3       2          0         1
# 59    63       0    2       0       0        3       0          1         2
# 69    74       0    2       2       0        3       2          0         1
# 78    84       0    2       1       2        1       2          1         1
# 80    86       0    2       1       4        2       0          3         2
# ...

# %%
df[df["age"] ==3] #"3" ifadesi ise 40 yaş ve üzeri müşterileri temsil etmektedir.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 24    25       0    3       1       3        3       0          2         2
# 28    29       0    3       1       4        1       1          0         1
# 47    51       0    3       2       3        3       0          0         2
# 49    53       1    3       3       0        2       2          0         2
# 99   106       0    3       2       2        2       1          1         2
# 105  115       0    3       1       1        3       0          1         2
# 108  118       0    3       1       1        2       0          2         1
#
#      membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 24                1  ...           5               1               1
# 28                0  ...           5               1               1
# 47                0  ...           4               1               1
# 49                0  ...           5               1               1
# ...

# %%
sns.countplot(data=df, x='age')
plt.title('Yaş')
plt.xticks([0, 1, 2, 3], ['20 yaşın altında', '20 - 29 yaş aralığı', '30 - 39 yaş aralığını', '40 yaş ve üzeri'])
plt.xlabel('') 
plt.tight_layout()
plt.show()
#Yaş seçeneğinde ise "0","1","2","3" olmak üzere 4 farklı değere sahibiz.
#"0" 20 yaşın altındakileri,
#"1" 20 - 29 yaş aralığını,
#"2" 30 - 39 yaş aralığını,
#"3" ifadesi ise 40 yaş ve üzeri müşterileri temsil etmektedir.
#Katılımcılar arasında 7 kişi 40 yaş ve üzeri
#17 kişi 30 - 39 yaş aralığında
#79 kişi 20-29 yaş aralığında
#10 kişi ise 20 yaş altındadır.

# %%
df["status"]
# Out:
# 0      0
# 1      0
# 2      2
# 3      0
# 4      0
#       ..
# 108    1
# 109    2
# 110    0
# 111    2
# 112    2
# Name: status, Length: 113, dtype: int64

# %%
df[df["status"] ==0] # "0" öğrencileri ifade eder.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# 5      6       1    1       0       0        3       0          1         2
# 6      7       1    1       0       0        3       0          0         0
# 8      9       1    1       0       0        3       1          0         2
# 10    11       1    1       0       0        3       0          0         2
# 11    12       1    1       0       0        3       0          1         2
# 12    13       1    1       0       0        1       2          0         1
# 13    14       1    1       0       0        3       2          0         1
# ...

# %%
df[df["status"] ==1] #"1" serbest meslek çalışanlarını ifade eder.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 19    20       1    1       1       2        3       2          0         1
# 24    25       0    3       1       3        3       0          2         2
# 27    28       0    1       1       0        2       2          0         2
# 28    29       0    3       1       4        1       1          0         1
# 36    37       1    1       1       0        3       2          0         0
# 44    48       1    1       1       0        3       2          1         2
# 63    67       1    1       1       1        2       0          0         0
# 77    83       0    1       1       2        3       0          2         2
# 78    84       0    2       1       2        1       2          1         1
# 80    86       0    2       1       4        2       0          3         2
# 81    87       0    1       1       4        3       1          1         2
# ...

# %%
df[df["status"] ==2] #"2" çalışanları ifade eder
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 2      3       0    1       2       0        2       0          1         2
# 7      8       0    1       2       2        3       0          1         2
# 9     10       0    1       2       0        2       2          0         2
# 15    16       1    1       2       0        3       2          1         2
# 16    17       0    2       2       2        2       1          0         0
# 17    18       0    1       2       0        3       0          0         0
# 18    19       0    1       2       1        1       2          0         1
# 20    21       0    2       2       3        3       2          0         0
# 21    22       1    1       2       0        3       0          0         0
# 22    23       0    1       2       1        3       0          4         0
# 25    26       0    2       2       4        2       0          1         1
# ...

# %%
df[df["status"] ==3] #"3" ev hanımlarını ifade eder
# Out:
#     Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 49  53       1    3       3       0        2       2          0         2
# 70  75       1    1       3       2        3       1          0         2
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 49               0  ...           5               1               1
# 70               1  ...           4               1               1
#
#     promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# 49                 1                1                  1                   1
# 70                 1                1                  1                   1
#
#     promoMethodBillboard  promoMethodOthers  loyal
# 49                     1                  1      0
# 70                     1                  1      0
#
# [2 rows x 33 columns]

# %%
sns.countplot(data=df, x='status')
plt.title('Meslek')
plt.xticks([0, 1, 2, 3], ['Öğrenciler', 'Serbest Meslek Çalışanları', 'Çalışanlar', 'Ev Hanımları'])
plt.xlabel('') 
plt.tight_layout()
plt.show()
#Meslek seçeneğinde ise "0","1","2","3" olmak üzere 4 farklı değere sahibiz.
#"0" öğrencileri ifade eder.
#"1" serbest meslek çalışanlarını ifade eder.
#"2" çalışanları ifade eder.
#"3" ifadesi ise ev hanımlarını temsil etmektedir.
# Katılımcılardan 2 kişi ev hanımı
#58 kişi çalışan
#16 kişi serbest meslek
#37 kişi ise öğrencidir.

# %%
df["income"] #Aylık Gelir Para birimi Malezya Ringgiti kullanıldığından dolayı açıklamalarda parabiriminin kısaltmasından "RM" olarak bahsedilecektir.
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 108    1
# 109    0
# 110    0
# 111    0
# 112    2
# Name: income, Length: 113, dtype: int64

# %%
df[df["income"] ==0] # "0" Aylık gelir 25.000 RM'den az.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 106  116       0    0       0       0        0       2          0         2
# 107  117       0    2       0       0        2       0          2         2
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
#
# ...

# %%
df[df["income"] ==1] #"1" Aylık gelir 25.000 ile 50.000 RM arası.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 18    19       0    1       2       1        1       2          0         1
# 22    23       0    1       2       1        3       0          4         0
# 30    31       1    1       2       1        2       2          1         2
# 32    33       1    2       2       1        3       2          0         2
# 33    34       1    1       2       1        3       0          1         1
# 34    35       1    1       2       1        3       2          0         0
# 41    43       1    1       2       1        1       0          1         0
# 45    49       1    1       2       1        3       2          0         0
# 51    55       1    1       2       1        3       2          1         0
# 52    56       1    1       2       1        2       2          1         1
# 63    67       1    1       1       1        2       0          0         0
# ...

# %%
df[df["income"] ==2] #"2" Aylık gelir 50.000 ile 100.000 RM arası.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 7      8       0    1       2       2        3       0          1         2
# 16    17       0    2       2       2        2       1          0         0
# 19    20       1    1       1       2        3       2          0         1
# 29    30       1    1       2       2        3       0          1         1
# 31    32       1    1       2       2        1       1          0         0
# 39    40       0    2       2       2        3       2          0         0
# 43    46       1    2       0       2        3       2          0         1
# 70    75       1    1       3       2        3       1          0         2
# 73    78       0    1       2       2        2       0          1         2
# 76    81       1    1       2       2        2       1          4         1
# 77    83       0    1       1       2        3       0          2         2
# ...

# %%
df[df["income"] ==3] #"3" Aylık gelir 100.000 ile 150.000 RM arası.
# Out:
#     Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 20  21       0    2       2       3        3       2          0         0
# 24  25       0    3       1       3        3       0          2         2
# 47  51       0    3       2       3        3       0          0         2
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 20               0  ...           3               1               1
# 24               1  ...           5               1               1
# 47               0  ...           4               1               1
#
#     promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# 20                 1                1                  1                   1
# 24                 1                1                  1                   1
# 47                 1                1                  1                   1
#
#     promoMethodBillboard  promoMethodOthers  loyal
# ...

# %%
df[df["income"] ==4] #"4" Aylık gelir 150.000 RM fazla.
# Out:
#     Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 25  26       0    2       2       4        2       0          1         1
# 26  27       0    2       2       4        3       1          0         1
# 28  29       0    3       1       4        1       1          0         1
# 80  86       0    2       1       4        2       0          3         2
# 81  87       0    1       1       4        3       1          1         2
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 25               0  ...           4               1               1
# 26               1  ...           2               1               1
# 28               0  ...           5               1               1
# 80               0  ...           4               1               1
# 81               0  ...           2               1               1
#
#     promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# ...

# %%
sns.countplot(data=df, x='income')
plt.title('Aylık Gelir')
plt.xticks([0, 1, 2, 3, 4], ["25.000 RM'den az", "25.000 ile 50.000 RM arası", "50.000 ile 100.000 RM arası", "100.000 ile 150.000 RM arası", "150.000 RM'den fazla"], rotation=45)
plt.xlabel('') 
plt.tight_layout()
plt.show()
#Meslek seçeneğinde ise "0","1","2","3" ve "4" olmak üzere 5 farklı değere sahibiz.
#"0" Aylık gelir 25.000 RM'den az.
#"1" Aylık gelir 25.000 ile 50.000 RM arası.
#"2" Aylık gelir 50.000 ile 100.000 RM arası.
#"3" Aylık gelir 100.000 ile 150.000 RM arası.
#"4" Aylık gelir 150.000 RM fazla.
# Katılımcılardan 65 kişi 25.000 Malezya Ringgiti'nden daha az bir aylık gelire sahip.
#23 kişi 25.000 ile 50.000 RM arasında bir gelire sahip.
#17 kişi 50.000 ile 100.000 RM arası
#3 kişi 100.000 ile 150.000 RM arası
#Kalan 5 kişinin aylık geliri 150.000 RM fazla.

# %%
df["visitNo"]
#Ziyaret etme aralığı seçeneğinde ise "0","1","2","3" ve "4" olmak üzere 5 farklı değere sahibiz.
#"0" Gün.
#"1" Hafta.
#"2" Ay.
#"3" Asla.
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      2
#       ..
# 108    2
# 109    2
# 110    3
# 111    3
# 112    3
# Name: visitNo, Length: 113, dtype: int64

# %%
df[df["visitNo"] ==0] #"0" Gün.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 96   103       0    1       1       2        0       1          0         2
# 106  116       0    0       0       0        0       2          0         2
#
#      membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 96                0  ...           3               1               1
# 106               1  ...           5               1               1
#
#      promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# 96                  1                1                  1                   1
# 106                 1                1                  1                   1
#
#      promoMethodBillboard  promoMethodOthers  loyal
# 96                      1                  1      0
# 106                     1                  1      0
#
# [2 rows x 33 columns]

# %%
df[df["visitNo"] ==1] #"1" Hafta.
# Out:
#      Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 12   13       1    1       0       0        1       2          0         1
# 18   19       0    1       2       1        1       2          0         1
# 28   29       0    3       1       4        1       1          0         1
# 31   32       1    1       2       2        1       1          0         0
# 41   43       1    1       2       1        1       0          1         0
# 67   72       0    1       2       1        1       2          2         0
# 78   84       0    2       1       2        1       2          1         1
# 85   91       1    2       2       2        1       0          2         2
# 97  104       0    2       2       1        1       0          2         2
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 12               0  ...           4               1               1
# 18               0  ...           5               1               1
# ...

# %%
df[df["visitNo"] ==2] #"2" Ay.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 2      3       0    1       2       0        2       0          1         2
# 4      5       0    1       0       0        2       2          1         1
# 9     10       0    1       2       0        2       2          0         2
# 16    17       0    2       2       2        2       1          0         0
# 23    24       1    1       0       0        2       1          2         1
# 25    26       0    2       2       4        2       0          1         1
# 27    28       0    1       1       0        2       2          0         2
# 30    31       1    1       2       1        2       2          1         2
# 40    42       0    1       2       0        2       0          1         0
# 42    44       1    1       2       0        2       2          0         2
# 49    53       1    3       3       0        2       2          0         2
# ...

# %%
df[df["visitNo"] ==3] #"3" Asla.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 3      4       1    1       0       0        3       2          0         2
# 5      6       1    1       0       0        3       0          1         2
# 6      7       1    1       0       0        3       0          0         0
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 104  114       1    0       0       0        3       2          0         2
# 105  115       0    3       1       1        3       0          1         2
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
# ...

# %%
sns.countplot(data=df, x='visitNo')
plt.title('Ziyaret Etme Aralığı')
plt.xticks([0, 1, 2, 3, ], ['Gün', 'Hafta', 'Ay', 'Asla'])
plt.xlabel('') 
plt.tight_layout()
plt.show()
#"0" Gün.
#"1" Hafta.
#"2" Ay.
#"3" Asla.
# 113 katılımcı arasında 76 kişi herhangi bir sıklıkla gelmediklerin belirtirken,
#26 kişi Aylık periyotlarla geldiklerini belirtmişlerdir.
#9 kişi haftalık periyotlarla geldiklerini belirtirken 2 kişi ise günlük periyotlarla geldiklerini belirtmiştir.

# %%
df["timeSpend"] #Harcanan süreyi ifade eder.
#"0" 30 dakikadan az.
#"1" 30 dakika ile 1 saat arasında.
#"2" 1 saat ile 2 saat arasında.
#"3" 2 saat ile 3 saat arasında.
#"4" 3 saatten daha fazla.
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 108    2
# 109    2
# 110    1
# 111    0
# 112    1
# Name: timeSpend, Length: 113, dtype: int64

# %%
df[df["timeSpend"] ==0] #"0" 30 dakikadan az.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 1      2       1    1       0       0        3       2          0         1
# 3      4       1    1       0       0        3       2          0         2
# 6      7       1    1       0       0        3       0          0         0
# 8      9       1    1       0       0        3       1          0         2
# 9     10       0    1       2       0        2       2          0         2
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 102  111       0    1       0       0        3       2          0         2
# 103  112       1    1       2       0        2       2          0         2
# 104  114       1    0       0       0        3       2          0         2
# 106  116       0    0       0       0        0       2          0         2
# 111  121       1    1       2       0        3       2          0         0
#
# ...

# %%
df[df["timeSpend"] ==1] #"1" 30 dakika ile 1 saat arasında.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 2      3       0    1       2       0        2       0          1         2
# 4      5       0    1       0       0        2       2          1         1
# 5      6       1    1       0       0        3       0          1         2
# 7      8       0    1       2       2        3       0          1         2
# 11    12       1    1       0       0        3       0          1         2
# 15    16       1    1       2       0        3       2          1         2
# 25    26       0    2       2       4        2       0          1         1
# 29    30       1    1       2       2        3       0          1         1
# 30    31       1    1       2       1        2       2          1         2
# 33    34       1    1       2       1        3       0          1         1
# ...

# %%
df[df["timeSpend"] ==2] #"2" 1 saat ile 2 saat arasında.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 23    24       1    1       0       0        2       1          2         1
# 24    25       0    3       1       3        3       0          2         2
# 37    38       0    0       0       0        3       0          2         2
# 57    61       0    1       0       0        3       0          2         1
# 67    72       0    1       2       1        1       2          2         0
# 77    83       0    1       1       2        3       0          2         2
# 79    85       0    1       2       1        3       0          2         2
# 85    91       1    2       2       2        1       0          2         2
# 97   104       0    2       2       1        1       0          2         2
# 107  117       0    2       0       0        2       0          2         2
# 108  118       0    3       1       1        2       0          2         1
# ...

# %%
df[df["timeSpend"] ==3] #"3" 2 saat ile 3 saat arasında.
# Out:
#     Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 80  86       0    2       1       4        2       0          3         2
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 80               0  ...           4               1               1
#
#     promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# 80                 1                1                  1                   1
#
#     promoMethodBillboard  promoMethodOthers  loyal
# 80                     1                  1      0
#
# [1 rows x 33 columns]

# %%
df[df["timeSpend"] ==4] #"4" 3 saatten daha fazla.
# Out:
#     Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 22  23       0    1       2       1        3       0          4         0
# 76  81       1    1       2       2        2       1          4         1
#
#     membershipCard  ...  chooseRate  promoMethodApp  promoMethodSoc  \
# 22               1  ...           3               1               1
# 76               0  ...           3               1               1
#
#     promoMethodEmail  promoMethodDeal  promoMethodFriend  promoMethodDisplay  \
# 22                 1                1                  1                   1
# 76                 1                1                  1                   1
#
#     promoMethodBillboard  promoMethodOthers  loyal
# 22                     1                  1      1
# 76                     1                  1      1
#
# [2 rows x 33 columns]

# %%
sns.countplot(data=df, x='timeSpend')
plt.title('Geçirilen Vakit')
plt.xticks([0, 1, 2, 3, 4], ["30 dakikadan az", "30 dakika ile 1 saat arasında", "1 saat ile 2 saat arasında", "2 saat ile 3 saat arasında", "3 saatten daha fazla"], rotation=45)
plt.xlabel('') 
plt.tight_layout()
plt.show()
#"0" 30 dakikadan az.
#"1" 30 dakika ile 1 saat arasında.
#"2" 1 saat ile 2 saat arasında.
#"3" 2 saat ile 3 saat arasında.
#"4" 3 saatten daha fazla.
# Ankete katılan ve bu şubeyi kullanan 64 kişi 30 dakikadan daha az vakit geçirdiklerini belirtmişir.
# 34 kişi 30 dakika ve 1 saat arasında vakit geçirdiklerini belirmiş.
# 12 kişi 1 saat ile 2 saat aralığında vakit geçirdiklerini belirtmiş.
# 1 kişi 2 ila 3 saat arası vakit geçirdiğini belirtmiş.
# Kalan 2 kişi ise 3 saatten fazla vakit geçirdiğini belirtmiştir.

# %%
df["location"]
#"0" 1 km içinde bir mesafede.
#"1" 1km ile  3km içinde bir mesafede
#"2" 3 kmden fazla bir mesafede
# Out:
# 0      0
# 1      1
# 2      2
# 3      2
# 4      1
#       ..
# 108    1
# 109    1
# 110    1
# 111    0
# 112    1
# Name: location, Length: 113, dtype: int64

# %%
df[df["location"] ==0] #"0" 1 km içinde bir mesafede.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 6      7       1    1       0       0        3       0          0         0
# 14    15       1    1       0       0        3       2          0         0
# 16    17       0    2       2       2        2       1          0         0
# 17    18       0    1       2       0        3       0          0         0
# 20    21       0    2       2       3        3       2          0         0
# 21    22       1    1       2       0        3       0          0         0
# 22    23       0    1       2       1        3       0          4         0
# 31    32       1    1       2       2        1       1          0         0
# 34    35       1    1       2       1        3       2          0         0
# 36    37       1    1       1       0        3       2          0         0
# ...

# %%
df[df["location"] ==1] #"1" 1km ile  3km içinde bir mesafede
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 1      2       1    1       0       0        3       2          0         1
# 4      5       0    1       0       0        2       2          1         1
# 12    13       1    1       0       0        1       2          0         1
# 13    14       1    1       0       0        3       2          0         1
# 18    19       0    1       2       1        1       2          0         1
# 19    20       1    1       1       2        3       2          0         1
# 23    24       1    1       0       0        2       1          2         1
# 25    26       0    2       2       4        2       0          1         1
# 26    27       0    2       2       4        3       1          0         1
# 28    29       0    3       1       4        1       1          0         1
# 29    30       1    1       2       2        3       0          1         1
# ...

# %%
df[df["location"] ==2] #"2" 3 kmden fazla bir mesafede
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 5      6       1    1       0       0        3       0          1         2
# 7      8       0    1       2       2        3       0          1         2
# 8      9       1    1       0       0        3       1          0         2
# 9     10       0    1       2       0        2       2          0         2
# 10    11       1    1       0       0        3       0          0         2
# 11    12       1    1       0       0        3       0          1         2
# 15    16       1    1       2       0        3       2          1         2
# 24    25       0    3       1       3        3       0          2         2
# 27    28       0    1       1       0        2       2          0         2
# ...

# %%
sns.countplot(data=df, x='location')
plt.title('Lokasyon')
plt.xticks([0, 1, 2], ['1 km içinde bir mesafede', '1km ile  3km içinde bir mesafede', '3 kmden fazla bir mesafede'], rotation=45)
plt.xlabel('') 
plt.tight_layout()
plt.show()
#"0" 1 km içinde bir mesafede.
#"1" 1km ile  3km içinde bir mesafede
#"2" 3 kmden fazla bir mesafede
# 56 kişi bu şubeye gelmek için 3 km'den daha fazla bir mesafe katederken, 32 kişi 1 ile 3 km arası bir mesafeden gelmiş,
# Kalan 25 kişi ise 1 km'den daha kısa bir mesafeden gelmiştir.

# %%
df["method"]
#"0"  Akşam Yemeği.
#"1" Arabaya Servis
#"2" Paket Servis
#"3" Asla
#"4" Diğer
# Out:
# 0      0
# 1      2
# 2      0
# 3      2
# 4      2
#       ..
# 108    0
# 109    0
# 110    0
# 111    2
# 112    0
# Name: method, Length: 113, dtype: int64

# %%
df[df["method"] ==0] #"0"  Akşam Yemeği.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 2      3       0    1       2       0        2       0          1         2
# 5      6       1    1       0       0        3       0          1         2
# 6      7       1    1       0       0        3       0          0         0
# 7      8       0    1       2       2        3       0          1         2
# 10    11       1    1       0       0        3       0          0         2
# 11    12       1    1       0       0        3       0          1         2
# 17    18       0    1       2       0        3       0          0         0
# 21    22       1    1       2       0        3       0          0         0
# 22    23       0    1       2       1        3       0          4         0
# 24    25       0    3       1       3        3       0          2         2
# ...

# %%
df[df["method"] ==1] #"1" Arabaya Servis
# Out:
#      Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 8     9       1    1       0       0        3       1          0         2
# 16   17       0    2       2       2        2       1          0         0
# 23   24       1    1       0       0        2       1          2         1
# 26   27       0    2       2       4        3       1          0         1
# 28   29       0    3       1       4        1       1          0         1
# 31   32       1    1       2       2        1       1          0         0
# 46   50       0    0       0       0        3       1          0         0
# 50   54       1    0       0       0        3       1          0         2
# 53   57       1    1       2       0        3       1          0         1
# 56   60       1    1       0       0        3       1          0         2
# 58   62       1    1       2       0        3       1          0         1
# ...

# %%
df[df["method"] ==2] #"2" Paket Servis
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 1      2       1    1       0       0        3       2          0         1
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# 9     10       0    1       2       0        2       2          0         2
# 12    13       1    1       0       0        1       2          0         1
# 13    14       1    1       0       0        3       2          0         1
# 14    15       1    1       0       0        3       2          0         0
# 15    16       1    1       2       0        3       2          1         2
# 18    19       0    1       2       1        1       2          0         1
# 19    20       1    1       1       2        3       2          0         1
# 20    21       0    2       2       3        3       2          0         0
# ...

# %%
df[df["method"] ==3]  ##"3" Asla. Veri setinin kaggledaki çıktısını kontrol ettiğimde hata olduğunu ve bir kişinin 5 olarak girdiğini gördüm
# Out:
# Empty DataFrame
# Columns: [Id, gender, age, status, income, visitNo, method, timeSpend, location, membershipCard, itemPurchaseCoffee, itempurchaseCold, itemPurchasePastries, itemPurchaseJuices, itemPurchaseSandwiches, itemPurchaseOthers, spendPurchase, productRate, priceRate, promoRate, ambianceRate, wifiRate, serviceRate, chooseRate, promoMethodApp, promoMethodSoc, promoMethodEmail, promoMethodDeal, promoMethodFriend, promoMethodDisplay, promoMethodBillboard, promoMethodOthers, loyal]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[df["method"] ==4] #"4" Diğer
# Out:
# Empty DataFrame
# Columns: [Id, gender, age, status, income, visitNo, method, timeSpend, location, membershipCard, itemPurchaseCoffee, itempurchaseCold, itemPurchasePastries, itemPurchaseJuices, itemPurchaseSandwiches, itemPurchaseOthers, spendPurchase, productRate, priceRate, promoRate, ambianceRate, wifiRate, serviceRate, chooseRate, promoMethodApp, promoMethodSoc, promoMethodEmail, promoMethodDeal, promoMethodFriend, promoMethodDisplay, promoMethodBillboard, promoMethodOthers, loyal]
# Index: []
#
# [0 rows x 33 columns]

# %%
sns.countplot(data=df, x='method')
plt.title('Sipariş Yöntemi')
plt.xticks([0, 1, 2, 3, 4 ], ['Akşam Yemeği', 'Arabaya Servis', 'Paket Servis', 'Asla', 'Diğer'])
plt.xlabel('') 
plt.tight_layout()
plt.show()
#"0"  Akşam Yemeği.
#"1" Arabaya Servis
#"2" Paket Servis
#"3" Asla
#"4" Diğer
# Diğer ve asla maddeleri tercih edilmemişken, 44 kişi akşam yemeği, 20 kişi arabaya servis, 48 kişi ise eve servis tercihinde bulunmuş.
# Veri setinin tam halini kontrol ettiğimde 1 kişinin anket seçeneklerinde bulunmayan 5 maddesini işaretlediğini tesbit ettim.

# %%
df["membershipCard"]
#"0"  Evet.
#"1" Hayır.
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 108    0
# 109    0
# 110    1
# 111    1
# 112    1
# Name: membershipCard, Length: 113, dtype: int64

# %%
df[df["membershipCard"] ==0]
#"0"  Evet.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 6      7       1    1       0       0        3       0          0         0
# 7      8       0    1       2       2        3       0          1         2
# 8      9       1    1       0       0        3       1          0         2
# 12    13       1    1       0       0        1       2          0         1
# 13    14       1    1       0       0        3       2          0         1
# 14    15       1    1       0       0        3       2          0         0
# 15    16       1    1       2       0        3       2          1         2
# 16    17       0    2       2       2        2       1          0         0
# ...

# %%
df[df["membershipCard"] ==1]
#"1"  Hayır.
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# 5      6       1    1       0       0        3       0          1         2
# 9     10       0    1       2       0        2       2          0         2
# 10    11       1    1       0       0        3       0          0         2
# 11    12       1    1       0       0        3       0          1         2
# 21    22       1    1       2       0        3       0          0         0
# 22    23       0    1       2       1        3       0          4         0
# 24    25       0    3       1       3        3       0          2         2
# 26    27       0    2       2       4        3       1          0         1
# 27    28       0    1       1       0        2       2          0         2
# ...

# %%
sns.countplot(data=df, x='membershipCard')
plt.title('Üyelik Kartı')
plt.xticks([0, 1], ['Evet', 'Hayır'])
plt.xlabel('')
plt.show()
#"0"  Evet.
#"1" Hayır.

## Ankete katılan 60 kişi Üyelik Kartı sahibiyken kalan 53 kişi bu kartı kullanmayı tercih etmemiş.

# %%
sns.countplot(x = "timeSpend",hue = "status",data = df)
#status:
#"0" öğrencileri ifade eder.
#"1" serbest meslek çalışanlarını ifade eder.
#"2" çalışanları ifade eder.
#"3" ifadesi ise ev hanımlarını temsil etmektedir.
#timeSpend
#"0" 30 dakikadan az.
#"1" 30 dakika ile 1 saat arasında.
#"2" 1 saat ile 2 saat arasında.
#"3" 2 saat ile 3 saat arasında.
#"4" 3 saatten daha fazla.
# Out:
# <Axes: xlabel='timeSpend', ylabel='count'>

# %%
sns.countplot(x = "visitNo",hue = "location",data = df)
#Ziyaret etme aralığı seçeneğinde ise "0","1","2","3" ve "4" olmak üzere 5 farklı değere sahibiz.
#"0" Gün.
#"1" Hafta.
#"2" Ay.
#Lokasyon
#"0" 1 km içinde bir mesafede.
#"1" 1km ile  3km içinde bir mesafede
#"2" 3 kmden fazla bir mesafede
# Out:
# <Axes: xlabel='visitNo', ylabel='count'>

# %%
sns.countplot(x = "location",hue = "method",data = df)
#Lokasyon
#"0" 1 km içinde bir mesafede.
#"1" 1km ile  3km içinde bir mesafede
#"2" 3 kmden fazla bir mesafede
#Method
#"0"  Akşam Yemeği.
#"1" Arabaya Servis
#"2" Paket Servis
#"3" Asla
#"4" Diğer
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %%
df = df.drop(["loyal","promoMethodOthers", "promoMethodBillboard", "promoMethodDisplay", "promoMethodFriend", "promoMethodDeal", "promoMethodEmail", "promoMethodSoc", "promoMethodApp", "chooseRate", "serviceRate", "wifiRate", "ambianceRate", "promoRate", "priceRate", "productRate", "spendPurchase", "itemPurchaseOthers", "itemPurchaseSandwiches", "itemPurchaseJuices", "itemPurchasePastries","itempurchaseCold", "itemPurchaseCoffee"], axis=1)

# %%
df.describe().T
# Out:
#                 count       mean        std  min   25%   50%   75%    max
# Id              113.0  60.150442  35.566392  1.0  29.0  60.0  90.0  122.0
# gender          113.0   0.522124   0.501735  0.0   0.0   1.0   1.0    1.0
# age             113.0   1.185841   0.675445  0.0   1.0   1.0   1.0    3.0
# status          113.0   1.221239   0.932877  0.0   0.0   2.0   2.0    3.0
# income          113.0   0.761062   1.087874  0.0   0.0   0.0   1.0    4.0
# visitNo         113.0   2.557522   0.718854  0.0   2.0   3.0   3.0    3.0
# method          113.0   1.070796   0.979402  0.0   0.0   1.0   2.0    5.0
# timeSpend       113.0   0.610619   0.849723  0.0   0.0   0.0   1.0    4.0
# location        113.0   1.274336   0.804538  0.0   1.0   1.0   2.0    2.0
# membershipCard  113.0   0.469027   0.501263  0.0   0.0   0.0   1.0    1.0

# %% [markdown]
# ## Veri Setinden Çıkarımlar

# %%
#CİNSİYET
#Cinsiyet seçeneğinde 59 kadın ve 54 erkek bulunmaktadır.
#YAŞ
#Katılımcılar arasında 7 kişi 40 yaş ve üzeri
#17 kişi 30 - 39 yaş aralığında
#79 kişi 20-29 yaş aralığında
#10 kişi ise 20 yaş altındadır.
#MESLEK GRUBU
# Katılımcılardan 2 kişi ev hanımı
#58 kişi çalışan
#16 kişi serbest meslek
#37 kişi ise öğrencidir.
#AYLIK GELİR
# Katılımcılardan 65 kişi 25.000 Malezya Ringgiti'nden daha az bir aylık gelire sahip.
#23 kişi 25.000 ile 50.000 RM arasında bir gelire sahip.
#17 kişi 50.000 ile 100.000 RM arası
#3 kişi 100.000 ile 150.000 RM arası
#Kalan 5 kişinin aylık geliri 150.000 RM fazla.
#ŞUBEYİ KULLANMA SIKLIĞI
# 113 katılımcı arasında 76 kişi herhangi bir sıklıkla gelmediklerin belirtirken,
#26 kişi Aylık periyotlarla geldiklerini belirtmişlerdir.
#9 kişi haftalık periyotlarla geldiklerini belirtirken 2 kişi ise günlük periyotlarla geldiklerini belirtmiştir.
# Ankete katılan ve bu şubeyi kullanan 64 kişi 30 dakikadan daha az vakit geçirdiklerini belirtmişir.
#ŞUBEDE GEÇİRİLEN VAKİT
# Ankete katılan ve bu şubeyi kullanan 64 kişi 30 dakikadan daha az vakit geçirdiklerini belirtmişir.
# 34 kişi 30 dakika ve 1 saat arasında vakit geçirdiklerini belirmiş.
# 12 kişi 1 saat ile 2 saat aralığında vakit geçirdiklerini belirtmiş.
# 1 kişi 2 ila 3 saat arası vakit geçirdiğini belirtmiş.
# Kalan 2 kişi ise 3 saatten fazla vakit geçirdiğini belirtmiştir.
#ŞUBEYE GELMEK İÇİN KAT EDİLEN MESAFE
# 56 kişi bu şubeye gelmek için 3 km'den daha fazla bir mesafe katederken, 32 kişi 1 ile 3 km arası bir mesafeden gelmiş,
# Kalan 25 kişi ise 1 km'den daha kısa bir mesafeden gelmiştir.
#SİPARİŞ YÖNTEMİ
# Diğer ve asla maddeleri tercih edilmemişken, 
# 44 kişi akşam yemeği, 20 kişi arabaya servis, 48 kişi ise eve servis tercihinde bulunmuş.
# Veri setinin tam halini kontrol ettiğimde 1 kişinin anket seçeneklerinde bulunmayan 5 maddesini işaretlediğini tesbit ettim.
#STARBUCKS ÜYELİK KART SAHİPLİĞİ
# Ankete katılan 60 kişi Üyelik Kartı sahibiyken kalan 53 kişi bu kartı kullanmayı tercih etmemiş.

# %%
df
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
#      membershipCard
# 0                 0
# ...
